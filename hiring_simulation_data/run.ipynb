# %%
# %run hiring_simulation_data.py
# Out:
# Generating data...
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40950 entries, 0 to 40949
# Data columns (total 10 columns):
# applicant_id              40950 non-null int64
# race                      40950 non-null object
# gender                    40950 non-null object
# application_date          40950 non-null object
# application_recieved      40950 non-null object
# application_evaluation    40950 non-null object
# certificate               40950 non-null object
# mananger_review_data      40950 non-null object
# interview_date            40950 non-null object
# offer_date                40950 non-null object
# dtypes: int64(1), object(9)
# memory usage: 3.1+ MB
#
#
# Now saving data to current directory...
